# %% [markdown]
# # Strategy Research
#
# ## Objective
#
# This notebook evaluates three systematic trading strategies:
#
# - SMA Crossover
# - RSI Mean Reversion
# - Momentum
#
# Each strategy is evaluated using the same historical dataset and identical backtesting assumptions.
#
# The objective is to compare:
#
# - Risk-adjusted performance
# - Drawdowns
# - Number of trades
# - Win rate
# - Portfolio suitability

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))
